# %%
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as ps
import pandas as pd

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(kind='scatter', data=tips, x = 'total_bill', y='tip')

# %%
sns.relplot(kind='scatter', data=tips, x = 'total_bill', y='tip', hue='sex')

# %%
sns.relplot(kind='scatter', data=tips, x = 'total_bill', y='tip', col='sex')
#sex column me jitni categories h utne scatter plot bna do side by side

# %%
sns.relplot(kind='scatter', data=tips, x = 'total_bill', y='tip', row='sex')

# %%
sns.relplot(kind='scatter', data=tips, x = 'total_bill', y='tip', row='smoker', col='sex')

# %%
sns.relplot(kind='scatter', data=tips, x = 'total_bill', y='tip', col='sex', row='day')

# %%
sns.relplot(kind='line', data=tips, x='total_bill', y='tip', row='sex', col='smoker')

# %%
sns.lineplot(data=tips, x = 'total_bill', y='tip', col='sex', row='smoker')
#facet plot will work only with figure level functions
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 sns.lineplot(data=tips, x = 'total_bill', y='tip', col='sex', row='smoker')
#
# File ~\anaconda3\Lib\site-packages\seaborn\relational.py:515, in lineplot(data, x, y, hue, size, style, units, weights, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     512 color = kwargs.pop("color", kwargs.pop("c", None))
#     513 kwargs["color"] = _default_color(ax.plot, hue, color, kwargs)
# --> 515 p.plot(ax, kwargs)
#     516 return ax
#
# File ~\anaconda3\Lib\site-packages\seaborn\relational.py:316, in _LinePlotter.plot(self, ax, kws)
#     314         lines.extend(ax.plot(unit_data["x"], unit_data["y"], **kws))
#     315 else:
# ...

# %%
gap = ps.data.gapminder()
gap
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
sns.relplot(data=gap, x='lifeExp', y='gdpPercap', kind='scatter')

# %%
sns.relplot(data=gap, x='lifeExp', y='gdpPercap', kind='scatter',col='year')

# %%
sns.relplot(data=gap, x='lifeExp', y='gdpPercap', kind='scatter',col='year', col_wrap=4)

# %%
sns.relplot(data=gap, x='lifeExp', y='gdpPercap', kind='scatter',col='year', col_wrap=5)
