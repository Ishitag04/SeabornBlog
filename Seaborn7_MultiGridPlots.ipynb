# %%
import seaborn as sns

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# figure level function: relplot, displot, catplot, lmplot

# %%
# Facetgrid
sns.catplot(data=tips, x='sex', y='total_bill', kind='violin', col='day', row='time')

# %%
# One more way of doing the above thing is using the facetgrid
# facetgrid gives more flexibiliy

# %%
g = sns.FacetGrid(data=tips, col='day', row='time')
g.map(sns.violinplot, 'sex', 'total_bill')
# Out:
# C:\Users\Ishita Garg\anaconda3\Lib\site-packages\seaborn\axisgrid.py:718: UserWarning: Using the violinplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
# Pair plot

# %%
iris = sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.pairplot(iris)

# %%
sns.pairplot(iris, hue='species')

# %%
# PairGrid

# %%
g = sns.PairGrid(data=iris)
g.map(sns.scatterplot)

# %%
g = sns.PairGrid(data=iris, hue='species')
g.map(sns.scatterplot)

# %%
g = sns.PairGrid(data=iris)
g.map_diag(sns.histplot)
g.map_offdiag(sns.scatterplot)

# %%
g = sns.PairGrid(data=iris, hue='species')
g.map_diag(sns.histplot)
g.map_offdiag(sns.scatterplot)

# %%
g = sns.PairGrid(data=iris, hue='species')
g.map_diag(sns.violinplot)
g.map_offdiag(sns.scatterplot)

# %%
g = sns.PairGrid(data=iris)
g.map_diag(sns.boxplot)
g.map_offdiag(sns.scatterplot)

# %%
g = sns.PairGrid(data=iris)
g.map_diag(sns.countplot)
g.map_offdiag(sns.scatterplot)

# %%
g = sns.PairGrid(data=iris)
g.map_diag(sns.boxplot)
g.map_offdiag(sns.histplot)

# %%
g = sns.PairGrid(data=iris, hue='species')
g.map_diag(sns.violinplot)
g.map_offdiag(sns.kdeplot)

# %%
g = sns.PairGrid(data=iris, hue='species')
g.map_diag(sns.histplot)
g.map_upper(sns.kdeplot)
g.map_lower(sns.scatterplot)

# %%
g = sns.PairGrid(data=iris, hue='species', vars=['sepal_length', 'sepal_width'])
g.map_diag(sns.histplot)
g.map_upper(sns.kdeplot)
g.map_lower(sns.scatterplot)

# %%
# Joint plot

# %%
sns.jointplot(data=tips, x='total_bill', y='tip')

# %%
sns.jointplot(data=tips, x='total_bill', y='tip', kind='scatter')

# %%
sns.jointplot(data=tips, x='total_bill', y='tip', kind='kde')

# %%
sns.jointplot(data=tips, x='total_bill', y='tip', kind='hist')

# %%
sns.jointplot(data=tips, x='total_bill', y='tip', kind='reg')

# %%
sns.jointplot(data=tips, x='total_bill', y='tip', kind='scatter1')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 sns.jointplot(data=tips, x='total_bill', y='tip', kind='scatter1')
#
# File ~\anaconda3\Lib\site-packages\seaborn\axisgrid.py:2223, in jointplot(data, x, y, hue, kind, height, ratio, space, dropna, xlim, ylim, color, palette, hue_order, hue_norm, marginal_ticks, joint_kws, marginal_kws, **kwargs)
#    2221 # Validate the plot kind
#    2222 plot_kinds = ["scatter", "hist", "hex", "kde", "reg", "resid"]
# -> 2223 _check_argument("kind", plot_kinds, kind)
#    2225 # Raise early if using `hue` with a kind that does not support it
#    2226 if hue is not None and kind in ["hex", "reg", "resid"]:
#
# File ~\anaconda3\Lib\site-packages\seaborn\utils.py:757, in _check_argument(param, options, value, prefix)
#     755     failure = value not in options
#     756 if failure:
# --> 757     raise ValueError(
#     758         f"The value for `{param}` must be one of {options}, "
#     759         f"but {repr(value)} was passed."
#     760     )
#     761 return value
#
# ValueError: The value for `kind` must be one of ['scatter', 'hist', 'hex', 'kde', 'reg', 'resid'], but 'scatter1' was passed.

# %%
# ['scatter', 'hist', 'hex', 'kde', 'reg', 'resid']
# These are the avaialbale kind parameters

# %%
sns.jointplot(data=tips, x='total_bill', y='tip', kind='hist', hue='sex')

# %%
# JointGrid

# %%
g = sns.JointGrid(data=tips)
g.plot(sns.scatterplot, sns.histplot)

# %%
g = sns.JointGrid(data=tips)
g.map(sns.scatterplot, sns.histplot)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[48], line 2
#       1 g = sns.JointGrid(data=tips)
# ----> 2 g.map(sns.scatterplot, sns.histplot)
#
# AttributeError: 'JointGrid' object has no attribute 'map'

# %%
g = sns.JointGrid(data=tips, x='total_bill', y='tip')
g.plot(sns.scatterplot, sns.histplot)

# %%
g = sns.JointGrid(data=tips, x='total_bill', y='tip')
g.plot(sns.histplot, sns.histplot)

# %%
g = sns.JointGrid(data=tips, x='total_bill', y='tip')
g.plot(sns.scatterplot, sns.kdeplot)

# %%
g = sns.JointGrid(data=tips, x='total_bill', y='tip')
g.plot(sns.scatterplot, sns.boxplot)

# %%
g = sns.JointGrid(data=tips, x='total_bill', y='tip')
g.plot(sns.scatterplot, sns.violinplot)

# %%
g = sns.JointGrid(data=tips, x='total_bill', y='tip')
g.plot(sns.kdeplot, sns.violinplot)

# %%
# Utility functions

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
# Load dataset

# %%
sns.load_dataset('flights')
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
sns.load_dataset('planets')
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]
